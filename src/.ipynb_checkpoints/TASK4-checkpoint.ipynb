# %%
#app.py

# !pip install streamlit
# !pip install pandas
# !pip install geopandas
# !pip install matplotlib
# !pip install folium
# !pip install streamlit-folium
# Out:
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/85/9e/146cdef515ad07e56c3aa942d087562498592d441aa3bae845ef0cd8fca3/streamlit-1.49.1-py3-none-any.whl.metadata
#   Downloading streamlit-1.49.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair!=5.4.0,!=5.4.1,<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Obtaining dependency information for blinker<2,>=1.5.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<7,>=4.0 (from streamlit)
#   Obtaining dependency information for cachetools<7,>=4.0 from https://files.pythonhosted.org/packages/6c/56/3124f61d37a7a4e7cc96afc5492c78ba0cb551151e530b54669ddd1436ef/cachetools-6.2.0-py3-none-any.whl.metadata
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in c:\users\usuario\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\usuario\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.17.3)
# Collecting narwhals>=1.14.2 (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit)
#   Obtaining dependency information for narwhals>=1.14.2 from https://files.pythonhosted.org/packages/f8/5a/22741c5c0e5f6e8050242bfc2052ba68bc94b1735ed5bca35404d136d6ec/narwhals-2.5.0-py3-none-any.whl.metadata
#   Downloading narwhals-2.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.49.1-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.0 MB 4.4 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/10.0 MB 3.9 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/10.0 MB 3.7 MB/s eta 0:00:03
#    -- ------------------------------------- 0.6/10.0 MB 3.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/10.0 MB 3.1 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/10.0 MB 3.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.1/10.0 MB 3.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.2/10.0 MB 3.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/10.0 MB 3.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/10.0 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/10.0 MB 3.5 MB/s eta 0:00:03
#    -------- ------------------------------- 2.0/10.0 MB 3.5 MB/s eta 0:00:03
#    -------- ------------------------------- 2.2/10.0 MB 3.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.5/10.0 MB 3.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.7/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.0 MB 3.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.0/10.0 MB 3.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.0 MB 3.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.3/10.0 MB 3.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.5/10.0 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.6/10.0 MB 3.7 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.0 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.1/10.0 MB 3.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.3/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.8 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.0 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.0 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 5.1/10.0 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.3/10.0 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.5/10.0 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/10.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/10.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/10.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.5/10.0 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 6.7/10.0 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.9/10.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.0 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.5/10.0 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/10.0 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/10.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.2/10.0 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 8.2/10.0 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/10.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.6/10.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.0 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/10.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 9.3/10.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 9.5/10.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 9.7/10.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  9.8/10.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 3.8 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ------------ --------------------------- 235.5/731.2 kB 4.8 MB/s eta 0:00:01
#    --------------------- ------------------ 399.4/731.2 kB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 563.2/731.2 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  727.0/731.2 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  727.0/731.2 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 731.2/731.2 kB 2.6 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.0-py3-none-any.whl (11 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#    ---------------------------------------- 0.0/208.2 kB ? eta -:--:--
#    ---------------------------------------  204.8/208.2 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 208.2/208.2 kB 4.2 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/6.9 MB 12.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/6.9 MB 8.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.9/6.9 MB 7.0 MB/s eta 0:00:01
#    ------ --------------------------------- 1.1/6.9 MB 5.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.3/6.9 MB 5.5 MB/s eta 0:00:02
#    -------- ------------------------------- 1.4/6.9 MB 5.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/6.9 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/6.9 MB 4.4 MB/s eta 0:00:02
#    --------- ------------------------------ 1.7/6.9 MB 4.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.9 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.9/6.9 MB 3.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.1/6.9 MB 3.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.3/6.9 MB 3.8 MB/s eta 0:00:02
#    --------------- ------------------------ 2.6/6.9 MB 3.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.8/6.9 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.9/6.9 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/6.9 MB 3.8 MB/s eta 0:00:02
#    ------------------ --------------------- 3.2/6.9 MB 3.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 3.8 MB/s eta 0:00:01
#    -------------------- ------------------- 3.6/6.9 MB 3.8 MB/s eta 0:00:01
#    --------------------- ------------------ 3.8/6.9 MB 3.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.0/6.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.9 MB 3.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.3/6.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.9 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.8/6.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/6.9 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.1/6.9 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 5.3/6.9 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 5.6/6.9 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 4.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.1/6.9 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 6.4/6.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/6.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  6.9/6.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 4.1 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.8 kB ? eta -:--:--
#    ---------------------------------------- 62.8/62.8 kB 3.5 MB/s eta 0:00:00
# Downloading narwhals-2.5.0-py3-none-any.whl (407 kB)
#    ---------------------------------------- 0.0/407.3 kB ? eta -:--:--
#    ------- -------------------------------- 71.7/407.3 kB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 317.4/407.3 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 407.3/407.3 kB 3.6 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, narwhals, cachetools, blinker, pydeck, gitdb, altair, gitpython, streamlit
# Successfully installed altair-5.5.0 blinker-1.9.0 cachetools-6.2.0 gitdb-4.0.12 gitpython-3.1.45 narwhals-2.5.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.49.1
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: geopandas in c:\users\usuario\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (1.24.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (2.3.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\usuario\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\usuario\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: folium in c:\users\usuario\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\usuario\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\usuario\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (from folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\usuario\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\usuario\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium) (2025.8.3)
# Collecting streamlit-folium
#   Obtaining dependency information for streamlit-folium from https://files.pythonhosted.org/packages/74/cc/de69b7248a1a3e31090cb98f3ab1a14be70665cbb8b55d4d33286145c4cb/streamlit_folium-0.25.1-py3-none-any.whl.metadata
#   Downloading streamlit_folium-0.25.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: streamlit>=1.13.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit-folium) (1.49.1)
# Requirement already satisfied: folium!=0.15.0,>=0.13 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit-folium) (0.20.0)
# Requirement already satisfied: jinja2 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit-folium) (3.1.2)
# Requirement already satisfied: branca in c:\users\usuario\anaconda3\lib\site-packages (from streamlit-folium) (0.8.1)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (from folium!=0.15.0,>=0.13->streamlit-folium) (1.24.3)
# Requirement already satisfied: requests in c:\users\usuario\anaconda3\lib\site-packages (from folium!=0.15.0,>=0.13->streamlit-folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\usuario\anaconda3\lib\site-packages (from folium!=0.15.0,>=0.13->streamlit-folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from jinja2->streamlit-folium) (2.1.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (6.2.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (8.0.4)
# Requirement already satisfied: packaging<26,>=20 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (23.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (2.3.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (9.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (6.32.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (11.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\usuario\anaconda3\lib\site-packages (from streamlit>=1.13.0->streamlit-folium) (6.3.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\usuario\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (4.17.3)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\usuario\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (2.5.0)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit>=1.13.0->streamlit-folium) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (5.0.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (25.3.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.13.0->streamlit-folium) (1.16.0)
# Downloading streamlit_folium-0.25.1-py3-none-any.whl (523 kB)
#    ---------------------------------------- 0.0/524.0 kB ? eta -:--:--
#    ---------- ----------------------------- 143.4/524.0 kB 2.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 368.6/524.0 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 524.0/524.0 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: streamlit-folium
# Successfully installed streamlit-folium-0.25.1

# %%
# Celda 2
#%%writefile app.py

import streamlit as st
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
from streamlit_folium import st_folium

# (Aquí va todo el código de la aplicación que te di antes)
# Lo incluyo de nuevo para que solo tengas que copiar y pegar esta celda

# --- Configuración de la página ---
st.set_page_config(
    page_title="Análisis de Hospitales Públicos en Perú",
    page_icon="🏥",
    layout="wide"
)

# --- Carga y Cache de Datos Reales ---
@st.cache_data
def load_data():

    hp_df = pd.read_csv('hospitals_info.csv')

    hp_df['LATITUD'] = pd.to_numeric(hp_df['NORTE'], errors='coerce')
    hp_df['LONGITUD'] = pd.to_numeric(hp_df['ESTE'], errors='coerce')
    hp_df.dropna(subset=['LATITUD', 'LONGITUD'], inplace=True)
    hp_df = hp_df[hp_df['LATITUD'].between(-18.5, 0)]
    hp_df = hp_df[hp_df['LONGITUD'].between(-81.5, -68.5)]

    hp_gdf = gpd.GeoDataFrame(
        hp_df,
        geometry=gpd.points_from_xy(hp_df['LONGITUD'], hp_df['LATITUD']),
        crs="EPSG:4326"
    )

    pop_gdf = gpd.read_file('CCPP_IGN100K.shp')
    if 'DEPARTAMEN' in pop_gdf.columns:
        pop_gdf.rename(columns={'DEP': 'DEPARTAMENTO'}, inplace=True)

    distritos_gdf = gpd.read_file('DISTRITOS.shp')
    peru_dptos_gdf = distritos_gdf.dissolve(by='DEPARTAMEN', aggfunc='sum')
    peru_dptos_gdf.reset_index(inplace=True)
    peru_dptos_gdf.rename(columns={'DEPARTAMEN': 'DEPARTAMENTO'}, inplace=True)

    return hp_gdf, pop_gdf, peru_dptos_gdf

hp_gdf, pop_gdf, peru_dptos_gdf = load_data()

# --- Procesamiento y Cálculos ---
dpto_summary = hp_gdf['Departamento'].value_counts().reset_index()
dpto_summary.columns = ['DEPARTAMENTO', 'N_HOSPITALES']
dpto_summary.rename(columns={'Departamento': 'DEPARTAMENTO'}, inplace=True)

peru_dptos_gdf = peru_dptos_gdf.merge(
    dpto_summary,
    how='left',
    on='DEPARTAMENTO'
)
peru_dptos_gdf['N_HOSPITALES'] = peru_dptos_gdf['N_HOSPITALES'].fillna(0)

def make_proximity_map(region_name, pop_gdf, hp_gdf, buffer_m=10000):
    pop_reg = pop_gdf[pop_gdf['DEPARTAMENTO'] == region_name]
    hp_reg = hp_gdf[hp_gdf['DEPARTAMENTO'] == region_name]

    if pop_reg.empty or hp_reg.empty:
        return folium.Map(location=[-9.19, -75.01], zoom_start=5, tiles='CartoDB positron')

    pop_reg_utm = pop_reg.to_crs("EPSG:32718")
    hp_reg_utm = hp_reg.to_crs("EPSG:32718")
    buffers_union_utm = hp_reg_utm.buffer(buffer_m).unary_union
    isolation = pop_reg_utm[~pop_reg_utm.within(buffers_union_utm)]
    concentration = pop_reg_utm[pop_reg_utm.within(buffers_union_utm)]

    map_center = [pop_reg.to_crs("EPSG:32718").geometry.unary_union.centroid.y, pop_reg.to_crs("EPSG:32718").geometry.unary_union.centroid.x]
    m = folium.Map(location=map_center, zoom_start=7, tiles='CartoDB positron')

    folium.GeoJson(gpd.GeoSeries([buffers_union_utm], crs="EPSG:32718").to_crs("EPSG:4326"), name='Área de Cobertura (10km)', style_function=lambda x: {'color': '#2a9d8f', 'fillColor': '#2a9d8f', 'fillOpacity': 0.3, 'weight': 1}).add_to(m)
    folium.GeoJson(isolation.to_crs("EPSG:4326"), name='Población Aislada', marker=folium.CircleMarker(radius=1.5, color='#e76f51', fill_color='#e76f51')).add_to(m)
    folium.GeoJson(concentration.to_crs("EPSG:4326"), name='Población con Cobertura', marker=folium.CircleMarker(radius=1.5, color='#2a9d8f', fill_color='#2a9d8f')).add_to(m)

    folium.LayerControl().add_to(m)
    return m

# --- Interfaz de Streamlit ---
st.title("🏥 Análisis de Infraestructura Hospitalaria Pública en Perú")

tab1, tab2, tab3 = st.tabs(["🗂️ Data Description", "🗺️ Static Maps & Department Analysis", "🌍 Dynamic Maps"])

with tab1:
    st.header("Descripción de los Datos")
    # ... (contenido de la pestaña 1)
with tab2:
    st.header("Análisis por Departamento")
    # ... (contenido de la pestaña 2)
with tab3:
    st.header("Mapa Nacional Interactivo")
    # ... (contenido de la pestaña 3)
# Out:
# 2025-09-18 23:32:07.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:07.939 No runtime found, using MemoryCacheStorageManager
# 2025-09-18 23:32:07.943 No runtime found, using MemoryCacheStorageManager
# 2025-09-18 23:32:07.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:07.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:07.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:07.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:12.845 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:12.893 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:12.899 Thread 'Thread-18': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.760 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-18 23:32:22.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
